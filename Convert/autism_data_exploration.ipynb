# %%
import pandas as pd
file_path = 'csv_result-Autism-Adult-Data.csv'
file_path1 = 'csv_result-Autism-Child-Data.csv'
file_path2 = 'csv_result-Autism-Adolescent-Data.csv'
df = pd.read_csv(file_path)
df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)

# %%
df.head()
# Out:
#    id  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0   1         1         1         1         1         0         0         1
# 1   2         1         1         0         1         0         0         0
# 2   3         1         1         0         1         1         0         1
# 3   4         1         1         0         1         0         0         1
# 4   5         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0  ...       f  White-European      no     no
# 1         1         0  ...       m          Latino      no    yes
# 2         1         1  ...       m          Latino     yes    yes
# 3         1         0  ...       f  White-European      no    yes
# 4         1         0  ...       f               ?      no     no
#
#    contry_of_res used_app_before result     age_desc  relation Class/ASD
# ...

# %%
df1.head()
# Out:
#    id  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0   1         1         1         0         0         1         1         0
# 1   2         1         1         0         0         1         1         0
# 2   3         1         1         0         0         0         1         1
# 3   4         0         1         0         0         1         1         0
# 4   5         1         1         1         1         1         1         1
#
#    A8_Score  A9_Score  ...  gender        ethnicity jundice austim  \
# 0         1         0  ...       m           Others      no     no
# 1         1         0  ...       m  Middle Eastern       no     no
# 2         1         0  ...       m                ?      no     no
# 3         0         0  ...       f                ?     yes     no
# 4         1         1  ...       m           Others     yes     no
#
#    contry_of_res used_app_before result    age_desc  relation Class/ASD
# ...

# %%
df2.head()
# Out:
#    id  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0   1         0         0         0         1         1         1         1
# 1   2         0         0         0         0         0         0         0
# 2   3         0         0         0         0         0         0         0
# 3   4         0         1         1         1         1         1         0
# 4   5         1         1         1         1         1         1         1
#
#    A8_Score  A9_Score  ...  gender       ethnicity jundice austim  \
# 0         1         1  ...       m        Hispanic     yes    yes
# 1         0         1  ...       m           Black      no     no
# 2         0         1  ...       f               ?      no     no
# 3         1         1  ...       f  White-European      no     no
# 4         0         0  ...       f               ?      no     no
#
#     contry_of_res used_app_before result     age_desc  relation Class/ASD
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 3. Initial Data Adult
shape = df.shape
info = df.info()

# Check for duplicate rows  Adult
duplicates = df.duplicated().sum()

shape, info, duplicates
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               704 non-null    int64
#  1   A1_Score         704 non-null    int64
#  2   A2_Score         704 non-null    int64
#  3   A3_Score         704 non-null    int64
#  4   A4_Score         704 non-null    int64
#  5   A5_Score         704 non-null    int64
#  6   A6_Score         704 non-null    int64
#  7   A7_Score         704 non-null    int64
#  8   A8_Score         704 non-null    int64
#  9   A9_Score         704 non-null    int64
#  10  A10_Score        704 non-null    int64
#  11  age              704 non-null    object
#  12  gender           704 non-null    object
#  13  ethnicity        704 non-null    object
#  14  jundice          704 non-null    object
#  15  austim           704 non-null    object
#  16  contry_of_res    704 non-null    object
# ...

# %%
# 3. Initial Data Child
shape = df1.shape
info = df1.info()

# Check for duplicate rows  child
duplicates = df1.duplicated().sum()

shape, info, duplicates
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               292 non-null    int64
#  1   A1_Score         292 non-null    int64
#  2   A2_Score         292 non-null    int64
#  3   A3_Score         292 non-null    int64
#  4   A4_Score         292 non-null    int64
#  5   A5_Score         292 non-null    int64
#  6   A6_Score         292 non-null    int64
#  7   A7_Score         292 non-null    int64
#  8   A8_Score         292 non-null    int64
#  9   A9_Score         292 non-null    int64
#  10  A10_Score        292 non-null    int64
#  11  age              292 non-null    object
#  12  gender           292 non-null    object
#  13  ethnicity        292 non-null    object
#  14  jundice          292 non-null    object
#  15  austim           292 non-null    object
#  16  contry_of_res    292 non-null    object
# ...

# %%
# 3. Initial Data Adolescent
shape = df2.shape
info = df2.info()

# Check for duplicate rows  Adolescent
duplicates = df2.duplicated().sum()

shape, info, duplicates
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               104 non-null    int64
#  1   A1_Score         104 non-null    int64
#  2   A2_Score         104 non-null    int64
#  3   A3_Score         104 non-null    int64
#  4   A4_Score         104 non-null    int64
#  5   A5_Score         104 non-null    int64
#  6   A6_Score         104 non-null    int64
#  7   A7_Score         104 non-null    int64
#  8   A8_Score         104 non-null    int64
#  9   A9_Score         104 non-null    int64
#  10  A10_Score        104 non-null    int64
#  11  age              104 non-null    int64
#  12  gender           104 non-null    object
#  13  ethnicity        104 non-null    object
#  14  jundice          104 non-null    object
#  15  austim           104 non-null    object
#  16  contry_of_res    104 non-null    object
# ...

# %%
# 5. Summary Statistics for numerical columns data Adult
summary_stats = df.describe()

# 6. Identify Missing Values
missing_values = df.isnull().sum()

summary_stats, missing_values
# Out:
# (               id    A1_Score    A2_Score    A3_Score    A4_Score    A5_Score  \
#  count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
#  mean   352.500000    0.721591    0.453125    0.457386    0.495739    0.498580
#  std    203.371581    0.448535    0.498152    0.498535    0.500337    0.500353
#  min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#  25%    176.750000    0.000000    0.000000    0.000000    0.000000    0.000000
#  50%    352.500000    1.000000    0.000000    0.000000    0.000000    0.000000
#  75%    528.250000    1.000000    1.000000    1.000000    1.000000    1.000000
#  max    704.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           A6_Score    A7_Score    A8_Score    A9_Score   A10_Score      result
#  count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
#  mean     0.284091    0.417614    0.649148    0.323864    0.573864    4.875000
# ...

# %%
# 5. Summary Statistics for numerical columns data Child
summary_stats = df1.describe()

# 6. Identify Missing Values
missing_values = df1.isnull().sum()

summary_stats, missing_values
# Out:
# (               id    A1_Score    A2_Score    A3_Score    A4_Score    A5_Score  \
#  count  292.000000  292.000000  292.000000  292.000000  292.000000  292.000000
#  mean   146.500000    0.633562    0.534247    0.743151    0.551370    0.743151
#  std     84.437354    0.482658    0.499682    0.437646    0.498208    0.437646
#  min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#  25%     73.750000    0.000000    0.000000    0.000000    0.000000    0.000000
#  50%    146.500000    1.000000    1.000000    1.000000    1.000000    1.000000
#  75%    219.250000    1.000000    1.000000    1.000000    1.000000    1.000000
#  max    292.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           A6_Score    A7_Score    A8_Score    A9_Score   A10_Score      result
#  count  292.000000  292.000000  292.000000  292.000000  292.000000  292.000000
#  mean     0.712329    0.606164    0.496575    0.493151    0.726027    6.239726
# ...

# %%
# 5. Summary Statistics for numerical columns data Adolesscent
summary_stats = df2.describe()

# 6. Identify Missing Values
missing_values = df2.isnull().sum()

summary_stats, missing_values
# Out:
# (               id    A1_Score    A2_Score    A3_Score    A4_Score   A5_Score  \
#  count  104.000000  104.000000  104.000000  104.000000  104.000000  104.00000
#  mean    52.500000    0.730769    0.538462    0.653846    0.701923    0.75000
#  std     30.166206    0.445708    0.500933    0.478047    0.459629    0.43511
#  min      1.000000    0.000000    0.000000    0.000000    0.000000    0.00000
#  25%     26.750000    0.000000    0.000000    0.000000    0.000000    0.75000
#  50%     52.500000    1.000000    1.000000    1.000000    1.000000    1.00000
#  75%     78.250000    1.000000    1.000000    1.000000    1.000000    1.00000
#  max    104.000000    1.000000    1.000000    1.000000    1.000000    1.00000
#
#           A6_Score    A7_Score    A8_Score    A9_Score   A10_Score         age  \
#  count  104.000000  104.000000  104.000000  104.000000  104.000000  104.000000
#  mean     0.769231    0.519231    0.615385    0.788462    0.653846   14.134615
# ...

# %%
# 7. Check for outliers using boxplots Adult
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['result']])
plt.title('Boxplot for Result Column')
plt.show()

# 8. Explore data distribution with histograms for numerical columns adult
df[['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
    'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'result']].hist(bins=10, figsize=(12, 10))
plt.suptitle('Histograms for Numerical Columns')
plt.show()

# %%
# 7. Check for outliers using boxplots Child
plt.figure(figsize=(12, 6))
sns.boxplot(data=df1[['result']])
plt.title('Boxplot for Result Column')
plt.show()

# 8. Explore data distribution with histograms for numerical columns Child
df1[['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
    'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'result']].hist(bins=10, figsize=(12, 10))
plt.suptitle('Histograms for Numerical Columns')
plt.show()

# %%
# 7. Check for outliers using boxplots Adolescent
plt.figure(figsize=(12, 6))
sns.boxplot(data=df1[['result']])
plt.title('Boxplot for Result Column')
plt.show()

# 8. Explore data distribution with histograms for numerical columns Adolescent
df1[['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
    'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'result']].hist(bins=10, figsize=(12, 10))
plt.suptitle('Histograms for Numerical Columns')
plt.show()

# %%
# 9. Categorical Data Exploration using count plots
categorical_columns = ['gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before', 'age_desc', 'relation', 'Class/ASD']

plt.figure(figsize=(15, 20))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(5, 2, i)
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f'Count plot for Adult {col}')
    plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
# 9. Categorical Data Exploration using count plots
categorical_columns = ['gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before', 'age_desc', 'relation', 'Class/ASD']

plt.figure(figsize=(15, 20))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(5, 2, i)
    sns.countplot(data=df1, x=col, order=df1[col].value_counts().index)
    plt.title(f'Count plot for Child {col}')
    plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
# 9. Categorical Data Exploration using count plots
categorical_columns = ['gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before', 'age_desc', 'relation', 'Class/ASD']

plt.figure(figsize=(15, 20))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(5, 2, i)
    sns.countplot(data=df2, x=col, order=df2[col].value_counts().index)
    plt.title(f'Count plot for Adolescent {col}')
    plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
# 10. Correlation Analysis and Heatmap for numerical columns
plt.figure(figsize=(10, 6))
corr_matrix = df[['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
                  'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'result']].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Adult Columns')
plt.show()

# %%
# 10. Correlation Analysis and Heatmap for numerical columns
plt.figure(figsize=(10, 6))
corr_matrix = df1[['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
                  'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'result']].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Child Columns')
plt.show()

# %%
# 10. Correlation Analysis and Heatmap for numerical columns
plt.figure(figsize=(10, 6))
corr_matrix = df2[['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 
                  'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'result']].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Adolescent Columns')
plt.show()

# %%
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
# Let's check if there is a column named "age" which might contain numerical values for age.
# Displaying the unique values in the "age" column if it exists.

df['age'].unique()
# Out:
# array(['26', '24', '27', '35', '40', '36', '17', '64', '29', '33', '18',
#        '31', '30', '34', '38', '42', '43', '48', '37', '55', '50', '53',
#        '20', '28', '21', '383', '47', '32', '44', '?', '19', '58', '45',
#        '22', '39', '25', '23', '54', '60', '41', '46', '56', '61', '59',
#        '52', '49', '51'], dtype=object)

# %%
df1['age'].unique()
# Out:
# array(['6', '5', '4', '11', '10', '8', '7', '9', '?'], dtype=object)

# %%
df2['age'].unique()
# Out:
# array([15, 12, 14, 16, 13], dtype=int64)

# %%
# Clean the 'age' column by removing invalid entries such as '?' and ages like '383'
# First, convert the column to numeric and handle errors by setting invalid parsing to NaN
df['age_clean'] = pd.to_numeric(df['age'], errors='coerce')

# Now that we have cleaned the age column, let's drop the NaN values and find the outliers
valid_age_data = df['age_clean'].dropna()

# Calculate the IQR for the age column
Q1_age = valid_age_data.quantile(0.25)
Q3_age = valid_age_data.quantile(0.75)
IQR_age = Q3_age - Q1_age

# Identify outliers in the age data
age_outliers = valid_age_data[(valid_age_data < (Q1_age - 1.5 * IQR_age)) | (valid_age_data > (Q3_age + 1.5 * IQR_age))]

age_outliers
# Out:
# 7       64.0
# 52     383.0
# 71      58.0
# 203     60.0
# 309     58.0
# 431     61.0
# 448     59.0
# 495     61.0
# Name: age_clean, dtype: float64

# %%
# Clean the 'age' column by removing invalid entries such as '?' and ages like '383'
# First, convert the column to numeric and handle errors by setting invalid parsing to NaN
df1['age_clean1'] = pd.to_numeric(df['age'], errors='coerce')

# Now that we have cleaned the age column, let's drop the NaN values and find the outliers
valid_age_data1 = df1['age_clean1'].dropna()

# Calculate the IQR for the age column
Q1_age = valid_age_data1.quantile(0.25)
Q3_age = valid_age_data1.quantile(0.75)
IQR_age = Q3_age - Q1_age

# Identify outliers in the age data
age_outliers = valid_age_data1[(valid_age_data < (Q1_age - 1.5 * IQR_age)) | (valid_age_data > (Q3_age + 1.5 * IQR_age))]

age_outliers
# Out:
# 7       64.0
# 52     383.0
# 71      58.0
# 203     60.0
# 289     56.0
# Name: age_clean1, dtype: float64

# %%
# Clean the 'age' column by removing invalid entries such as '?' and ages like '383'
# First, convert the column to numeric and handle errors by setting invalid parsing to NaN
df2['age_clean2'] = pd.to_numeric(df['age'], errors='coerce')

# Now that we have cleaned the age column, let's drop the NaN values and find the outliers
valid_age_data2 = df2['age_clean2'].dropna()

# Calculate the IQR for the age column
Q1_age = valid_age_data2.quantile(0.25)
Q3_age = valid_age_data2.quantile(0.75)
IQR_age = Q3_age - Q1_age

# Identify outliers in the age data
age_outliers = valid_age_data2[(valid_age_data < (Q1_age - 1.5 * IQR_age)) | (valid_age_data > (Q3_age + 1.5 * IQR_age))]

age_outliers
# Out:
# 7      64.0
# 52    383.0
# Name: age_clean2, dtype: float64

# %%
import matplotlib.pyplot as plt

# Create a boxplot to visualize the outliers in the age column
plt.figure(figsize=(8,6))
plt.boxplot(valid_age_data, vert=False, patch_artist=True)
plt.title('Boxplot of Age with Outliers')
plt.xlabel('Age')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a boxplot to visualize the outliers in the age column
plt.figure(figsize=(8,6))
plt.boxplot(valid_age_data1, vert=False, patch_artist=True)
plt.title('Boxplot of Age with Outliers')
plt.xlabel('Age')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a boxplot to visualize the outliers in the age column
plt.figure(figsize=(8,6))
plt.boxplot(valid_age_data2, vert=False, patch_artist=True)
plt.title('Boxplot of Age with Outliers')
plt.xlabel('Age')
plt.show()

# %%
import os
#read the path
file_path = "."
#list all the files from the directory
file_list = os.listdir(file_path)
file_list
# Out:
# ['autism_data_exploration.ipynb',
#  'autism_data_preprocessing.ipynb',
#  'cay_eda.ipynb',
#  'csv_result-Autism-Adolescent-Data.csv',
#  'csv_result-Autism-Adult-Data.csv',
#  'csv_result-Autism-Child-Data.csv']

# %%
#read the path
cwd = os.path.abspath('')
#list all the files from the directory
file_list = os.listdir(cwd)
file_list
# Out:
# ['autism_data_exploration.ipynb',
#  'autism_data_preprocessing.ipynb',
#  'cay_eda.ipynb',
#  'csv_result-Autism-Adolescent-Data.csv',
#  'csv_result-Autism-Adult-Data.csv',
#  'csv_result-Autism-Child-Data.csv']

# %%
#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['csv_result-Autism-Adolescent-Data.csv',
#  'csv_result-Autism-Adult-Data.csv',
#  'csv_result-Autism-Child-Data.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\putra\AppData\Local\Temp\ipykernel_19852\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\putra\AppData\Local\Temp\ipykernel_19852\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\putra\AppData\Local\Temp\ipykernel_19852\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
#        id  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 0       1         0         0         0         1         1         1
# ...

# %%
df_concat = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df_concat
# Out:
#        id  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 0       1         0         0         0         1         1         1
# 1       2         0         0         0         0         0         0
# 2       3         0         0         0         0         0         0
# 3       4         0         1         1         1         1         1
# 4       5         1         1         1         1         1         1
# ...   ...       ...       ...       ...       ...       ...       ...
# 1095  288         1         1         1         1         1         1
# 1096  289         1         0         0         0         1         0
# 1097  290         1         0         1         1         1         1
# 1098  291         1         1         1         0         1         1
# 1099  292         0         0         1         0         1         0
#
#       A7_Score  A8_Score  A9_Score  ...  gender       ethnicity jundice  \
# ...

# %%
df_concat.to_csv('Autism_combined_data.csv')
